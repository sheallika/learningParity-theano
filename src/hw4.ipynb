# %% [markdown]
# ## ECBM E4040 Homework 4 - Programming Problem

# %%
import theano
import hw4a
from hw4a import test_rnnslu,test_rnnslu2
from hw4b import test_mlp_parity,test_rnn_parity,test_lstm_parity
# Out:
# /usr/local/lib/python2.7/dist-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ### Problem a: Recurrent Neural Network
# #### Bullet 1: Experiment with RNNSLU

# %% [raw]
# The 2 values of the parameter taken for  size of context window are 7 and 13
# The 2 values for the parameter, dimension of word embeddings are 50 and 100
#
# the test results are almost same for all the parameter combination, which are documented below:
# 1) context window 7 and dim of word emb 50 : 94.2
# 2) context window 7 and dim of word emb 100 : 94.02
# 3) context window 13 and dim of word emb 50 : 93.79
# 4) context window 13 and dim of word emb 100 : 94.1

# %%
win=[7,13]
emb_dim=[50,100]
for i in win:
    for k in emb_dim:
        test_rnnslu(win=i,emb_dimension=k)
# Out:
# layer_normal: False
# verbose: True
# normal: True
# win: 7
# savemodel: True
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.18 best test F1 66.22
# NEW BEST: epoch 1 valid F1 80.63 best test F1 77.98
# NEW BEST: epoch 2 valid F1 83.79 best test F1 80.66
# NEW BEST: epoch 3 valid F1 88.42 best test F1 84.92
# NEW BEST: epoch 4 valid F1 89.65 best test F1 85.97
# NEW BEST: epoch 5 valid F1 91.02 best test F1 86.87
# NEW BEST: epoch 6 valid F1 91.45 best test F1 88.81
# NEW BEST: epoch 7 valid F1 92.05 best test F1 89.89
# NEW BEST: epoch 8 valid F1 93.78 best test F1 90.69
# NEW BEST: epoch 9 valid F1 94.19 best test F1 91.27
# NEW BEST: epoch 10 valid F1 94.7 best test F1 91.64
# NEW BEST: epoch 11 valid F1 94.88 best test F1 92.23
# NEW BEST: epoch 12 valid F1 95.4 best test F1 92.73
# ...

# %% [markdown]
# #### Bullet 2: Experiment with RNNSLU without normalizing word embeddings

# %% [raw]
# The best test result in setiing of 1, was obtained on:
# context window 7 and dim of word emb 50 : 94.2
# So, using win=7 and emb_dimension = 50 and normal=False lowered the test performance from 94.2 to 94.0.
#
# Length of word embeddings should not effect the result of the model. that is why it is normalised to lie on unit length sphere. This is observed to perform better than without normalisation.

# %%
test_rnnslu(win=7,emb_dimension=50,normal=False)
# Out:
# layer_normal: False
# verbose: True
# normal: False
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.96 best test F1 63.35
# NEW BEST: epoch 1 valid F1 81.28 best test F1 76.9
# NEW BEST: epoch 2 valid F1 84.73 best test F1 81.46
# NEW BEST: epoch 3 valid F1 88.04 best test F1 84.06
# NEW BEST: epoch 4 valid F1 90.05 best test F1 86.02
# NEW BEST: epoch 5 valid F1 91.31 best test F1 86.93
# NEW BEST: epoch 6 valid F1 92.65 best test F1 88.75
# NEW BEST: epoch 7 valid F1 93.21 best test F1 89.79
# NEW BEST: epoch 8 valid F1 94.0 best test F1 90.6
# NEW BEST: epoch 9 valid F1 94.86 best test F1 90.68
# NEW BEST: epoch 10 valid F1 95.13 best test F1 91.98
#
# NEW BEST: epoch 12 valid F1 95.68 best test F1 92.92
# NEW BEST: epoch 13 valid F1 95.91 best test F1 92.79
#
# ...

# %% [markdown]
# #### Bullet 3: Implement RNN with two hidden layers

# %% [raw]
# The best test result in setiing of 1, was obtained on:
# context window 7 and dim of word emb 50 : 94.2
# So, using win=7 and emb_dimension = 50 on the RNN with 2 hidden layers, with hidden layer 1 and 2 both having 200 hidden units.
#
# The test result on this model is 93.6

# %%
test_rnnslu2(win=7, emb_dimension=50, nhidden1, nhidden2=200,nepochs=100)
# Out:
# verbose: True
# nhidden2: 200
# win: 7
# nhidden1: 200
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 100
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 57.71 best test F1 52.52
# NEW BEST: epoch 1 valid F1 72.41 best test F1 69.87
# NEW BEST: epoch 2 valid F1 77.9 best test F1 75.03
# NEW BEST: epoch 3 valid F1 82.45 best test F1 80.06
# NEW BEST: epoch 4 valid F1 85.77 best test F1 81.83
# NEW BEST: epoch 5 valid F1 87.99 best test F1 83.85
# NEW BEST: epoch 6 valid F1 88.94 best test F1 85.86
# NEW BEST: epoch 7 valid F1 91.05 best test F1 88.8
# NEW BEST: epoch 8 valid F1 91.25 best test F1 88.51
# NEW BEST: epoch 9 valid F1 91.42 best test F1 88.66
# NEW BEST: epoch 10 valid F1 92.4 best test F1 90.02
# NEW BEST: epoch 11 valid F1 92.79 best test F1 89.82
# NEW BEST: epoch 12 valid F1 93.06 best test F1 89.97
# ...

# %% [markdown]
# #### Bullet 4: Experiment with layer normalization

# %% [raw]
# The 2 values of the parameter taken for  size of context window are 7 and 13
# The 2 values for the parameter, dimension of word embeddings are 50 and 100 and using the layer normalisation regularizer.
#
# the test results (are similar) have not improved (and are similar) much over the model without layer normalisation, but it converged faster than (in less number of epochs) without normalisation model.Results are documented below:
# 1) context window 7 and dim of word emb 50 : 93.97, 54 epochs (94.2, 57 epochs)
# 2) context window 7 and dim of word emb 100 : 93.95, 20 epochs (94.02, 59 epochs)
# 3) context window 13 and dim of word emb 50 : 93.76, 32 epochs (93.79, 55 epochs)
# 4) context window 13 and dim of word emb 100 : 93.49, 34 epochs (94.1, 37 epochs)
#
# In the brackets are the results for model without layer normalisation. The convergence speed is faster for layer normalisation model as compared to without normalisation model and both converge to values which are close enough.

# %%
import theano
from hw4a import test_rnnslu,test_rnnslu2
import hw4b
win=[7,13]
emb_dim=[50,100]
for i in win:
    for k in emb_dim:
        test_rnnslu(win=i,emb_dimension=k)
# Out:
# layer_normal: True
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# recurrence_layerNormalise in use
# ... training
# NEW BEST: epoch 0 valid F1 72.99 best test F1 69.0
# NEW BEST: epoch 1 valid F1 83.02 best test F1 79.45
# NEW BEST: epoch 2 valid F1 87.66 best test F1 84.02
# NEW BEST: epoch 3 valid F1 91.36 best test F1 87.77
# NEW BEST: epoch 4 valid F1 92.7 best test F1 88.49
# NEW BEST: epoch 5 valid F1 93.89 best test F1 90.68
#
# NEW BEST: epoch 7 valid F1 94.8 best test F1 92.37
# NEW BEST: epoch 8 valid F1 95.09 best test F1 92.31
# NEW BEST: epoch 9 valid F1 95.29 best test F1 92.58
# NEW BEST: epoch 10 valid F1 95.75 best test F1 92.49
#
# NEW BEST: epoch 12 valid F1 96.25 best test F1 93.41
#
# NEW BEST: epoch 14 valid F1 96.5 best test F1 93.16
# ...

# %% [markdown]
# #### Bullet 5: Observation on embedding pairs

# %%
# code to load the model

from __future__ import print_function
import six.moves.cPickle as pickle

from collections import OrderedDict
import copy
import numpy
import os
import random
import timeit

import theano
from theano import tensor as T

from hw4_utils import load_data, contextwin, shuffle, conlleval, check_dir
from hw4_nn import RNNSLU


def load_model(**kwargs):

        param = {
            'fold': 3,
            'lr': 0.0970806646812754,
            'verbose': True,
            'decay': True,
            'win': 7,
            'nhidden': 200,
            'seed': 345,
            'emb_dimension': 50,
            'nepochs': 60,
            'loadmodel': True,
            'normal': True,
            'layer_normal': False,
            'folder':'../result'}

        if(param['loadmodel']!=True):
            print ("Unable to load")
            sys.exit()


        param_diff = set(kwargs.keys()) - set(param.keys())
        if param_diff:
            raise KeyError("invalid arguments:" + str(tuple(param_diff)))
        param.update(kwargs)

        if param['verbose']:
            for k,v in param.items():
                print("%s: %s" % (k,v))

        # create result folder if not exists
        check_dir(param['folder'])

        # load the dataset
        print('... loading the dataset')
        train_set, valid_set, test_set, dic = load_data(param['fold'])

        # create mapping from index to label, and index to word
        idx2label = dict((k, v) for v, k in dic['labels2idx'].items())
        idx2word = dict((k, v) for v, k in dic['words2idx'].items())

        # unpack dataset
        train_lex, train_ne, train_y = train_set
        valid_lex, valid_ne, valid_y = valid_set
        test_lex, test_ne, test_y = test_set

        vocsize = len(dic['words2idx'])
        nclasses = len(dic['labels2idx'])
        nsentences = len(train_lex)

        groundtruth_valid = [map(lambda x: idx2label[x], y) for y in valid_y]
        words_valid = [map(lambda x: idx2word[x], w) for w in valid_lex]
        groundtruth_test = [map(lambda x: idx2label[x], y) for y in test_y]
        words_test = [map(lambda x: idx2word[x], w) for w in test_lex]

        # instanciate the model
        numpy.random.seed(param['seed'])
        random.seed(param['seed'])

        print('... building the model')
        rnn = RNNSLU(
            nh=param['nhidden'],
            nc=nclasses,
            ne=vocsize,
            de=param['emb_dimension'],
            cs=param['win'],
            normal=param['normal'],
            layer_normal=param['layer_normal'])
        rnn.load(param['folder'])
        return rnn, idx2label, idx2word

# %%
rnn, idx2label, idx2word = load_model()
word_vectors = rnn.emb.eval()
print ("Finding close pairs")

for i in range(0, word_vectors.shape[0]):
    for j in range(i, word_vectors.shape[0]):
        if i==j:
            continue
        distance = numpy.linalg.norm(word_vectors[i]- word_vectors[j])
        if distance < 0.5:
            print ("Pair of "+ idx2word[i]+ " and "+idx2word[j]+" is very close. [Euclidean Distance: +"+str(distance)+" ]")
# Out:
# layer_normal: False
# verbose: True
# normal: True
# win: 7
# loadmodel: True
# nepochs: 60
# fold: 3
# seed: 345
# emb_dimension: 50
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# Finding close pairs
# Pair of american and continental is very close. [Euclidean Distance: +0.455193437175 ]
# Pair of american and delta is very close. [Euclidean Distance: +0.419641416961 ]
# Pair of american and northwest is very close. [Euclidean Distance: +0.491469812624 ]
# Pair of arrive and arrives is very close. [Euclidean Distance: +0.498641341049 ]
# Pair of breakfast and dinner is very close. [Euclidean Distance: +0.304590663536 ]
# Pair of car and rental is very close. [Euclidean Distance: +0.335030538594 ]
# Pair of cheapest and less is very close. [Euclidean Distance: +0.441005922653 ]
# Pair of continental and delta is very close. [Euclidean Distance: +0.442766797155 ]
# ...

# %%
print ("Finding Minus Relationships")



rnn, idx2label, idx2word = load_model()
word_vectors = rnn.emb.eval()
print (len(word_vectors))
print (word_vectors.shape[0])
distance= {}
distance[(37,136)] = numpy.abs(numpy.asarray(word_vectors[373])-numpy.asarray(word_vectors[379]))
for i in range(0,len(word_vectors)):
    for j in range(0,len(word_vectors)):
        if i==j:
            continue
        distance[(i,j)] = numpy.abs(numpy.asarray(word_vectors[i])-numpy.asarray(word_vectors[j]))
        
        
# i have the distance of each pair stored
pair_distance=[]
# print (distance)
# Out:
# Finding Minus Relationships
# layer_normal: False
# verbose: True
# normal: True
# win: 7
# loadmodel: True
# nepochs: 60
# fold: 3
# seed: 345
# emb_dimension: 50
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# 573
# 573

# %%
key = (37,136)
count=1
for key2 in distance.keys():
    if(key!=key2):
        value  = numpy.linalg.norm(distance[key] - distance[key2])
        if (value < 0.4):
            i,j = key 
            k, l = key2
            if(count==100):
                break
            count+=1
            print (idx2word[i]+ " - "+idx2word[j]+" approximately equals "+ idx2word[k]+ " - "+idx2word[l]+" [Euclidean Distance: +"+str(value)+" ]")
# Out:
# american - delta approximately equals eastern - american [Euclidean Distance: +0.354589959856 ]
# american - delta approximately equals september - august [Euclidean Distance: +0.36130471913 ]
# american - delta approximately equals cheapest - less [Euclidean Distance: +0.393753488883 ]
# american - delta approximately equals limousine - rental [Euclidean Distance: +0.306391186944 ]
# american - delta approximately equals united - northwest [Euclidean Distance: +0.344808667104 ]
# american - delta approximately equals wednesday - thursday [Euclidean Distance: +0.393137736333 ]
# american - delta approximately equals monday - thursday [Euclidean Distance: +0.35566891337 ]
# american - delta approximately equals saturday - monday [Euclidean Distance: +0.315920834546 ]
# american - delta approximately equals rental - car [Euclidean Distance: +0.365416586464 ]
# american - delta approximately equals rental - train [Euclidean Distance: +0.367044613615 ]
# ...

# %%
distance ={}
distance[(1,2)]=1
print (distance)
# Out:
# {(1, 2): 1}

# %%
print (idx2word)
# Out:
# {0: "'d", 1: "'ll", 2: "'m", 3: "'re", 4: "'s", 5: "'t", 6: '72s', 7: '<UNK>', 8: 'DIGIT', 9: 'DIGITDIGIT', 10: 'DIGITDIGITDIGIT', 11: 'DIGITDIGITDIGITDIGIT', 12: 'DIGITDIGITDIGITDIGITDIGITDIGIT', 13: 'a', 14: 'abbreviation', 15: 'abbreviations', 16: 'about', 17: 'ac', 18: 'actually', 19: 'after', 20: 'afternoon', 21: 'again', 22: 'air', 23: 'aircraft', 24: 'airfare', 25: 'airline', 26: 'airlines', 27: 'airplane', 28: 'airplanes', 29: 'airport', 30: 'airports', 31: 'alaska', 32: 'all', 33: 'along', 34: 'also', 35: 'am', 36: 'america', 37: 'american', 38: 'amount', 39: 'an', 40: 'and', 41: 'angeles', 42: 'another', 43: 'any', 44: 'anywhere', 45: 'ap', 46: 'ap57', 47: 'ap80', 48: 'approximately', 49: 'april', 50: 'are', 51: 'area', 52: 'arizona', 53: 'around', 54: 'arrange', 55: 'arrangements', 56: 'arrival', 57: 'arrivals', 58: 'arrive', 59: 'arrives', 60: 'arriving', 61: 'as', 62: 'at', 63: 'atl', 64: 'atlanta', 65: 'august', 66: 'available', 67: 'b', 68: 'back', 69: 'baltimore', 70:
# ...

# %% [markdown]
# ### Problem b: Learning Parity Function
# #### Bullet 1: Shallow MLP

# %% [raw]
# The shallow MLP has 1 hidden layer.
# Depending upon the bit of the sequences the number of units in the hidden layer is different. The following architectures have achieved 100% test accuracy on the data:
# 1) for 8 bit sequences : 1 hidden layer, 800 hidden units, batch size= 50, 100% accuracy on test was achieved.
# 2) for 12 bit sequences : 1 hidden layer, 1200 hidden units, batch size= 50, 100% accuracy on test was achieved.

# %%
n_bit=[8,12]
n_layers=[800,1200]
for i,k in zip(n_bit,n_layers):
    
    test_mlp_parity(n_bit=i, n_hidden=k, n_hiddenLayers=1, n_epochs=1000, batch_size=50, verbose= True)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 80/80, validation error 50.200000 %
#      epoch 1, minibatch 80/80, test error of best model 52.000000 %
# training @ iter =  100
# epoch 2, minibatch 80/80, validation error 50.800000 %
# training @ iter =  200
# epoch 3, minibatch 80/80, validation error 50.800000 %
# training @ iter =  300
# epoch 4, minibatch 80/80, validation error 50.800000 %
# epoch 5, minibatch 80/80, validation error 50.800000 %
# training @ iter =  400
# epoch 6, minibatch 80/80, validation error 49.200000 %
#      epoch 6, minibatch 80/80, test error of best model 51.000000 %
# training @ iter =  500
# epoch 7, minibatch 80/80, validation error 49.200000 %
# training @ iter =  600
# epoch 8, minibatch 80/80, validation error 49.200000 %
# training @ iter =  700
# epoch 9, minibatch 80/80, validation error 49.200000 %
# epoch 10, minibatch 80/80, validation error 49.200000 %
# training @ iter =  800
# ...

# %% [markdown]
# #### Bullet 2: Deep MLP

# %% [raw]
# The Deep MLP has 3 hidden layers.
# Depending upon the bit of the sequences the number of units in the hidden layer is different. The following architectures have achieved 100% test accuracy on the data:
# 1) for 8 bit sequences : 3 hidden layer, 100 hidden units in layer 1, 50 hidden units in layer 2, 50 hidden units in layer 3, batch size= 50, 100% accuracy on test was achieved around 83 epoch.
# 2) for 12 bit sequences : 3 hidden layer, 100 hidden units in layer 1, 100 hidden units in layer 2, 100 hidden units in layer 3, batch size= 50, 100% accuracy on test was achieved around 312 epoch.
#
# The hidden units and epochs required in deep MLP are much less than that of what was required in shallow MLP to achieve 100% testing accuracy

# %%
n_bit=[8,12]
n_layers=[[100,50,50],[100,100,50]]
for i,k in zip(n_bit,n_layers):
    
    test_mlp_parity(n_bit=i, n_hidden=k, n_hiddenLayers=3, n_epochs=1000, batch_size=50, verbose= True)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 200/200, validation error 52.200000 %
#      epoch 1, minibatch 200/200, test error of best model 46.000000 %
# training @ iter =  200
# training @ iter =  300
# epoch 2, minibatch 200/200, validation error 52.200000 %
# training @ iter =  400
# training @ iter =  500
# epoch 3, minibatch 200/200, validation error 51.200000 %
#      epoch 3, minibatch 200/200, test error of best model 46.000000 %
# training @ iter =  600
# training @ iter =  700
# epoch 4, minibatch 200/200, validation error 51.200000 %
# training @ iter =  800
# training @ iter =  900
# epoch 5, minibatch 200/200, validation error 48.800000 %
#      epoch 5, minibatch 200/200, test error of best model 44.000000 %
# training @ iter =  1000
# training @ iter =  1100
# epoch 6, minibatch 200/200, validation error 48.000000 %
#      epoch 6, minibatch 200/200, test error of best model 43.000000 %
# ...

# %% [markdown]
# #### Bullet 3: RNN

# %% [raw]
# The RNN has 1 hidden layer
# Depending upon the bit of the sequences the number of units in the hidden layer is different. The following architectures have achieved 100% test accuracy for parity function:
# 1) for 8 bit sequences : 1 hidden layer, 3 hidden units, 100% accuracy on test was achieved
# 2) for 12 bit sequences : 1 hidden layer, 7 hidden units , 100% accuracy on test was achieved
#
# The hidden units required in RNN to learn parity function are way  much less than that of what was required in deep MLP to achieve 100% testing accuracy

# %%
n_bit=[8,12]
nhidden=[3,7]
for i,j in zip(n_bit,nhidden):
    test_rnn_parity(n_bit=i,nhidden=j,nepochs=100)
# Out:
# verbose: True
# win: 7
# n_bit: 8
# savemodel: True
# seed: 100
# nepochs: 100
# nhidden: 3
# decay: True
# lr: 0.197080664681
# is_rnn: 1
# folder: ../result_rnn
# ... loading the dataset
# ... building the model
# ... training
# ('NEW BEST: epoch 0', 'Validation Error 49.4%', 'Test Error 56.0%')
#
#
#
#
# ('NEW BEST: epoch 5', 'Validation Error 45.8%', 'Test Error 53.0%')
#
#
#
#
# ('NEW BEST: epoch 10', 'Validation Error 45.6%', 'Test Error 46.0%')
# ('NEW BEST: epoch 11', 'Validation Error 43.4%', 'Test Error 52.0%')
# ('NEW BEST: epoch 12', 'Validation Error 39.6%', 'Test Error 43.0%')
# ('NEW BEST: epoch 13', 'Validation Error 0.0%', 'Test Error 0.0%')
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ('Best Result : epoch 13', 'Validation Error 0.0%', 'Best Test Error 0.0%', 'on 8 bit sequences')
# verbose: True
# win: 7
# n_bit: 12
# savemodel: True
# seed: 100
# nepochs: 100
# nhidden: 7
# decay: True
# lr: 0.197080664681
# is_rnn: 1
# folder: ../result_rnn
# ...

# %% [markdown]
# #### Bullet 4: LSTM

# %% [raw]
# The LSTM has 1 hidden layer and using only 1 hidden unit 100% test accuracy can be achieved for parity function for both 8 bit and 12 bit sequences
#
# The hidden units required in LSTM to learn parity function are the least.

# %%
n_bit=[8,12]
nhidden=[1,1]
for i,j in zip(n_bit,nhidden):
    test_lstm_parity(n_bit=i,nhidden=j,nepochs=60)
# Out:
# nhidden: 1
# verbose: True
# decay: True
# n_bit: 8
# savemodel: True
# seed: 345
# lr: 0.1
# is_rnn: 1
# folder: ../result_lstm
# nepochs: 60
# ... building the model
# ... training
# ('NEW BEST: epoch', 0, 'validation error', 0.50375000000000003, 'test error', 0.4975)
#
#
#
# ('NEW BEST: epoch', 4, 'validation error', 0.37624999999999997, 'test error', 0.36249999999999999)
# ('NEW BEST: epoch', 5, 'validation error', 0.312, 'test error', 0.29999999999999999)
# ('NEW BEST: epoch', 6, 'validation error', 0.0, 'test error', 0.0)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# param[clr] < 1e-5
# ('BEST result : epoch', 56, 'best validation error', 0.0, 'test error', 0.0, 'on 8 bit sequences')
# nhidden: 1
# verbose: True
# decay: True
# n_bit: 12
# savemodel: True
# seed: 345
# lr: 0.1
# is_rnn: 1
# folder: ../result_lstm
# nepochs: 60
# ... building the model
# ... training
# ...
